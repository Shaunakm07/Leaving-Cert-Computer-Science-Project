# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.4.2-py3-none-any.whl.metadata (38 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /Users/shaunak/.local/lib/python3.12/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: protobuf in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (4.25.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shaunak/miniconda3/envs/deep_learning/lib/python3.12/site-packages (from requests->kagglehub) (2025.11.12)
# Downloading kagglehub-0.4.2-py3-none-any.whl (69 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
# Successfully installed kagglehub-0.4.2 kagglesdk-0.1.15
#
# [notice] A new release of pip is available: 24.2 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
import kagglehub
import shutil
import os

path = kagglehub.dataset_download("ziya07/plant-health-data")

dest = os.path.join(os.getcwd(), "plant-health-data")
shutil.copytree(path, dest, dirs_exist_ok=True)
# Out:
# '/Users/shaunak/Desktop/Leaving Cert Computer Science Project/Python Modelling/plant-health-data'

# %%
import pandas as pd
dataset = pd.read_csv("plant-health-data/plant_health_data.csv")

dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               1200 non-null   object
#  1   Plant_ID                1200 non-null   int64
#  2   Soil_Moisture           1200 non-null   float64
#  3   Ambient_Temperature     1200 non-null   float64
#  4   Soil_Temperature        1200 non-null   float64
#  5   Humidity                1200 non-null   float64
#  6   Light_Intensity         1200 non-null   float64
#  7   Soil_pH                 1200 non-null   float64
#  8   Nitrogen_Level          1200 non-null   float64
#  9   Phosphorus_Level        1200 non-null   float64
#  10  Potassium_Level         1200 non-null   float64
#  11  Chlorophyll_Content     1200 non-null   float64
#  12  Electrochemical_Signal  1200 non-null   float64
#  13  Plant_Health_Status     1200 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 131.4+ KB
#                     Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0  2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1  2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2  2024-10-03 22:54:53.407995         1      17.086362            21.180946
# 3  2024-10-04 04:54:53.407995         1      15.336156            22.593302
# 4  2024-10-04 10:54:53.407995         1      39.822216            28.929001
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
# 2         15.392939  67.837956       591.124627  5.656852       29.337002
# 3         22.778394  58.190811       241.412476  5.584523       16.966621
# 4         18.100937  63.772036       444.493830  5.919707       10.944961
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# 0         45.806852        39.076199            35.703006
# 1         25.394393        17.944826            27.993296
# 2         27.573892        35.706530            43.646308
# 3         26.180705        26.257746            37.838095
# 4         37.898907        37.654483            48.265812
#
#    Electrochemical_Signal Plant_Health_Status
# 0                0.941402         High Stress
# 1                0.164899         High Stress
# 2                1.081728         High Stress
# 3                1.186088         High Stress
# 4                1.609805         High Stress
